# %% [markdown]
# <h1 style="border-radius: 8px; border: 2px solid red; padding: 8px; text-align:center;">Statistics for Data Science Workshop 03</h1>

# %%
from Binomial import Binomial
from Exponential import Exponential
from Normal import Normal
from Poisson import Poisson

# %% [markdown]
# ## Binomial

# %% [markdown]
# ### Example

# %%
Binomial.hist_bar_kdeplot(0.4)

# %% [markdown]
# ### Approximation

# %%
Binomial.superimpose_kde_plots(0.5)

# %% [markdown]
# ## Poisson

# %%
Poisson.hist_bar_kdeplot(1.8)

# %% [markdown]
# ### Approximation

# %%
Poisson.superimpose_kde_plots(50)

# %% [markdown]
# ## Exponential

# %% [markdown]
# ### Example

# %%
Exponential.hist_bar_kdeplot(1.8)

# %% [markdown]
# ## Normal

# %% [markdown]
# ### Example

# %%
Normal.hist_bar_kdeplot(2, 0.5)
